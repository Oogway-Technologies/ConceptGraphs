# %%
test_text = """To my Chris, I have been thinking
about how I could possibly tell you
how much you mean to me. I remember
when I first started to fall in
love with you like it was last
night. Lying naked beside you in
that tiny apartment, it suddenly
hit me that I was part of this
whole larger thing, just like our
parents, and our parents' parents.
Before that I was just living my
life like I knew everything, and
suddenly this bright light hit me
and woke me up. That light was you."""

# Text -> chunks -> sentences -> concepts

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import SystemMessage
import spacy
import json
from const import *
from prompts import *
from utils import *
import uuid

# %%
nlp = spacy.load("en_core_web_md")

# %%
def chunk_text():
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=250,
        chunk_overlap=20,
        length_function=len,
        is_separator_regex=False,
        separators=['. ', '.\n']
    )
    doc = Document(page_content=test_text, metadata={"title": "Poem"})
    pages = text_splitter.split_documents([doc])
    return [(page.page_content, page.metadata) for page in pages]

# %%
def extract_triplet(text, context):
    # 1) create langchain callback OpenAI
    # 2) get JSON string representing [(c1, c2, relation)]
    # 3) convert to JSON
    # 4) return JSON = [(c1, c2, relation)]
    chat = ChatOpenAI(
        api_key=OPENAI_API_KEY,
        model_name="gpt-3.5-turbo-0125",
        temperature=0,
        max_tokens=1000,
    )
    system_message_prompt = SystemMessage(content=system_message)
    human_message_prompt = HumanMessagePromptTemplate.from_template(task_message)
    chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
    messages = chat_prompt.format_prompt(
        context=context,
        target=text,
    ).to_messages()
    res = chat.invoke(messages)
    
    res = str(res.content).strip()
    res = '[' + str(res) if res[0] != '[' else str(res)
    res = add_missing_commas(res)
    res = res.replace(',,', ',')
    try:
        json_res = json.loads(res)
    except:
        print('-----')
        print(res)
        return []

    for r in json_res:
        r['edge'] = r.pop('relation')
        r['id'] = str(uuid.uuid4())

    return json_res

# %%
def llm_extraction():
    # (Concept1, Concept2, relation)
    triplets = []

    res = chunk_text()
    for text, metadata in res:
        doc = nlp(text)
        for sent in doc.sents:
            sentence_text = sent.text
            sentence_text += "." if sent.text[-1] != "." else ""
            triplet = extract_triplet(sentence_text, text)
            # print(triplet)
            triplets.extend(triplet)
    
    df, G = get_dataframe_graph(triplets)
    print(df)
    df.to_csv('poem.csv')

# %%
llm_extraction()
# Out:
#           source sourceConceptType              target targetConceptType  \
# 0              I            entity               Chris            entity
# 1              I            entity            to think             event
# 2              I            entity                 you            entity
# 3       to think             event               Chris            entity
# 4       to think             event             meaning  abstract concept
# 5        meaning  abstract concept                 you            entity
# 6              I            entity            remember             event
# 7       remember             event        fall in love             event
# 8   fall in love             event                 you            entity
# 9   fall in love             event          last night             event
# 10             I            entity                 you            entity
# 11           you            entity              beside             event
# 12           you            entity           apartment            entity
# 13     apartment            entity                tiny  abstract concept
# 14             I            entity             part of             event
# 15             I            entity  whole larger thing  abstract concept
# 16             I            entity                 you            entity
# 17           you            entity               lying             event
# 18           you            entity           apartment            entity
# 19             I            entity                part  abstract concept
# 20          part  abstract concept               thing            entity
# 21         thing            entity             parents            entity
# 22       parents            entity    parents' parents            entity
# 23             I            entity                life  abstract concept
# 24          life  abstract concept           knowledge  abstract concept
# 25  bright light            entity                   I            entity
# 26  bright light            entity           awakening             event
# 27     awakening             event                   I            entity
# 28             I            entity                life            entity
# 29             I            entity             to live             event
# 30          life            entity                   I            entity
# 31             I            entity           knowledge  abstract concept
# 32     knowledge  abstract concept                   I            entity
# 33  bright light            entity                   I            entity
# 34  bright light            entity          to wake up             event
# 35         light            entity                 you            entity
# 36         light            entity                 you            entity
#
#                                             semantics  \
# 0   The pronoun 'I' refers to the speaker who is e...
# 1   The verb 'thinking' is an action performed by ...
# 2   The pronoun 'you' refers to 'Chris', indicatin...
# 3   The act of 'thinking' is directed towards 'Chr...
# 4   The thought process involves contemplating 'ho...
# 5   The significance of 'you' to the speaker is ex...
# 6   The pronoun 'I' refers to the speaker who is r...
# 7   The act of 'remembering' is associated with th...
# 8   The event of 'falling in love' is directed tow...
# 9   The event of 'falling in love' is compared to ...
# 10  The pronoun 'I' refers to the speaker who is r...
# 11  The preposition 'beside' indicates the spatial...
# 12  The noun 'apartment' refers to the location wh...
# 13  The adjective 'tiny' describes the size of the...
# 14  The phrase 'part of' indicates the speaker's r...
# 15  The expression 'whole larger thing' conveys th...
# 16  The pronoun 'I' refers to the speaker who is r...
# 17  The action of 'lying' is associated with 'you'...
# 18  The location of 'that tiny apartment' is where...
# 19  The speaker realizes that they are 'part of th...
# 20  The concept of 'part' is connected to 'thing' ...
# 21  The 'thing' refers to the family lineage or ge...
# 22  The 'parents' are further extended to 'parents...
# 23  The pronoun 'I' refers to the speaker who was ...
# 24  The concept of 'knowing everything' is associa...
# 25  The 'bright light' is described as impacting t...
# 26  The 'bright light' serves as a catalyst for th...
# 27  The 'awakening' experience is attributed to th...
# 28  The pronoun 'I' refers to the speaker who is r...
# 29  The verb 'living' describes the actions taken ...
# 30  The concept of 'life' is directly associated w...
# 31  The pronoun 'I' reflects on the concept of 'kn...
# 32  The abstract concept of 'knowing everything' i...
# 33  The 'bright light' is described as impacting t...
# 34  The 'bright light' is associated with the acti...
# 35  The 'light' is metaphorically referring to 'yo...
# 36  The 'light' is metaphorically referring to 'yo...
#
#                                       edge  \
# 0               Expresses feelings towards
# 1                              Reflects on
# 2                       Directly addresses
# 3                      Focuses thoughts on
# 4   Contemplates emotional significance of
# 5        Expresses emotional value towards
# 6                                  Recalls
# 7                          Associated with
# 8                         Directed towards
# 9                              Compares to
# 10             Reflects on experience with
# 11     Describes spatial relationship with
# 12                    Shares location with
# 13                       Describes size of
# 14                   Realizes belonging to
# 15                 Perceives connection to
# 16             Reflects on experience with
# 17                             Involves in
# 18                              Located in
# 19                   Realizes belonging to
# 20                            Component of
# 21                              Related to
# 22              Multi-generational link to
# 23                     Experiences life as
# 24                         Associated with
# 25                                 Impacts
# 26                                Leads to
# 27                                 Affects
# 28                             Reflects on
# 29                    Describes actions in
# 30                         Associated with
# 31                             Reflects on
# 32                           Attributed to
# 33                                 Impacts
# 34                         Associated with
# 35               Metaphorically represents
# 36               Metaphorically represents
#
#                                       id
# 0   fb5efa2d-fb46-4b45-9245-5eed6dd22e48
# 1   d9b1ee7d-92d8-464f-a9dd-b24285bc548b
# 2   bcb5220e-9fc3-49aa-b697-0e0c98303345
# 3   4157e093-92ea-4815-84f0-c7a7771722d4
# 4   2dab5aa5-45a7-49ca-b189-51588db9757c
# 5   0af6f375-0ce1-442b-8157-c8148e524a91
# 6   ce84d03e-0e0a-42b1-b8da-c011acda0f77
# 7   8c6efc15-fd18-4a87-b591-8d4ab8bfb118
# 8   f9ea44b8-2c3d-4a39-a183-67c63288a000
# 9   3b708636-989b-4389-96f9-556a62e76204
# 10  29e8d50c-43e7-49ec-8d55-413c885655d2
# 11  e2980baa-cd1d-429f-ae37-3a48d24614b0
# 12  90a04465-4d60-487a-b430-4060c421a842
# 13  bae0bb10-4562-49ee-9711-972de0519f22
# 14  12344266-248d-4873-b653-d7ab9b18d4af
# 15  82df666f-f423-4741-94bc-09c6a14f518b
# 16  33842073-b19b-455d-8b33-50af8f0689e4
# 17  3cc7e083-2a34-4dd3-950d-eaf0056dc978
# 18  a9c7582c-e3bc-42e4-b310-b740a63bb898
# 19  5018711b-4aa9-4b70-90b7-40f96210c08a
# 20  2590a443-f9d2-4fa2-adea-0fcc66b25f18
# 21  9cb3deda-6e7f-4450-ae3f-458906d184b4
# 22  031728f0-898d-45ff-93d9-632630b68c7c
# 23  f2c15ff9-094d-4deb-88ec-506df77bd0c8
# 24  3499b3b3-2821-452d-9d27-e0ed807017b2
# 25  44bb2a70-4e66-4008-8178-75f300d31dfd
# 26  89d6172a-e58b-4788-b969-c3c471748e35
# 27  707884f2-636f-42ae-85bb-e7e3e3c8d945
# 28  dcb19449-7a8f-4c81-ab43-263ab0b98a2d
# 29  8ddc1264-05a4-4425-8e74-bf6a37f3d993
# 30  9a13400c-0f51-4b5c-82ee-c6d13e900500
# 31  e5853815-e8a6-4ffa-92f5-dc49faf5c130
# 32  a8ca1c24-327d-4752-b33b-36cb9f05f6c6
# 33  cf8133ff-9b64-4a11-9174-29d5fcbaae6a
# 34  db36d4e4-a02b-426f-98d4-31cf97633988
# 35  03f9fe00-a984-4754-a7fc-1c70939c844a
# 36  2dfe4975-8984-4ab6-ba26-1ec9b4d1cba0

# %%
from pyvis.network import Network

df = pd.read_csv('poem.csv')
df = df[["source", "target", "edge"]]
G = nx.from_pandas_edgelist(df, 'source', 'target', edge_attr=True, create_using=nx.MultiDiGraph())

# Plot Network
net = Network(height="750px", width="100%")
# net.from_nx(G)
for _, row in df.iterrows():
    net.add_node(row['source'], label=row['source'])
    net.add_node(row['target'], label=row['target'])
    net.add_edge(row['source'], row['target'], label=row['edge'])

net.show("poem.html", notebook=False)
# Out:
# poem.html
